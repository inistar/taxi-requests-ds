# %%
import pandas as pd
import numpy as np

import geopandas as gpd
from shapely.geometry import Point
import rtree
import pickle

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
event_list_df = pd.read_csv("data/NYC_Parks_Events_Listing___Event_Listing.csv", parse_dates=True)

# %%
loc_df = pd.read_csv('data/NYC_Parks_Events_Listing___Event_Locations.csv')

# %%
cat_df = pd.read_csv('data/NYC_Parks_Events_Listing___Event_Categories.csv')

# %%
org_df = pd.read_csv('data/NYC_Parks_Events_Listing___Event_Organizers.csv')

# %%
event_list_df['start_time'] = pd.to_datetime(event_list_df['start_time'], format='%H:%M')

# %%
event_list_df[event_list_df.end_time == '24:00']
# Out:
#        event_id                                      title        date  \
# 11088     79666  New Year's Eve Fireworks in Prospect Park  12/31/2013
# 23359    102431                   New Year's Eve Fireworks  12/31/2014
#
#                start_time end_time location_description  \
# 11088 1900-01-01 23:00:00    24:00                  NaN
# 23359 1900-01-01 23:00:00    24:00                  NaN
#
#                                              description  \
# 11088  <p>\n\tStart the celebrations off around 11 p....
# 23359  <p>Kick off the New Year&#39;s with this belov...
#
#                                                  snippet phone email  \
# 11088  Start the celebrations off around 11 p.m. with...   NaN   NaN
# 23359  Kick off the New Year's with this beloved Broo...   NaN   NaN
#
#        cost_free cost_description  must_see                       url  notice
# 11088          1              NaN         1  new-years-eve-fireworks1       0
# 23359          1              NaN         1   new-years-eve-fireworks       0

# %%
event_list_df = event_list_df.drop(event_list_df.index[23359])
event_list_df = event_list_df.drop(event_list_df.index[11088])

# %%
event_list_df[event_list_df.end_time == '24:00']
# Out:
# Empty DataFrame
# Columns: [event_id, title, date, start_time, end_time, location_description, description, snippet, phone, email, cost_free, cost_description, must_see, url, notice]
# Index: []

# %%
event_list_df['end_time'] = pd.to_datetime(event_list_df['end_time'], format='%H:%M')

# %%
event_list_df['date'] = pd.to_datetime(event_list_df.date)

# %%
event_list_df['is_event'] = 1

# %%
event_list_df['event_duration'] = ((event_list_df.end_time-event_list_df.start_time).dt.total_seconds())/60

# %%
event_list_df['DOW'] = event_list_df.date.dt.weekday_name

# %%
event_list_df['TOD'] = event_list_df.start_time.dt.hour

# %%
event_list_df.date.dt.

# %%
event_list_df['is_weekend'] = ((event_list_df.date.dt.dayofweek) // 5 == 1).astype(float)

# %%
cat_df.name.unique().shape
# Out:
# (122,)

# %%
org_df.event_organizer.unique().shape
# Out:
# (2237,)

# %%
event_list_df = event_list_df[event_list_df.date.dt.year == 2017]

# %%
merged_df = pd.merge(event_list_df, loc_df, on=['event_id'])

# %%
merged_df = pd.merge(merged_df, cat_df, on=['event_id'])

# %%
merged_df = pd.merge(merged_df, org_df, on=['event_id'])

# %%
merged_df.head()
# Out:
#    event_id                                              title       date  \
# 0    107941                     Conference House Art Expo 2017 2017-05-20
# 1    107941                     Conference House Art Expo 2017 2017-05-20
# 2    107941                     Conference House Art Expo 2017 2017-05-20
# 3    107941                     Conference House Art Expo 2017 2017-05-20
# 4    108867  Thursday Evening Hours at the Merchant’s House... 2017-01-05
#
#            start_time            end_time location_description  \
# 0 1900-01-01 11:00:00 1900-01-01 17:00:00                  NaN
# 1 1900-01-01 11:00:00 1900-01-01 17:00:00                  NaN
# 2 1900-01-01 11:00:00 1900-01-01 17:00:00                  NaN
# 3 1900-01-01 11:00:00 1900-01-01 17:00:00                  NaN
# 4 1900-01-01 12:00:00 1900-01-01 20:00:00                  NaN
#
#                                          description  \
# 0  <p>Come view original artworks and tree instal...
# 1  <p>Come view original artworks and tree instal...
# 2  <p>Come view original artworks and tree instal...
# 3  <p>Come view original artworks and tree instal...
# 4  <p>Beginning May 7, 2015, the Merchant’s House...
#
#                                              snippet           phone  \
# 0  Come view original artworks and tree installat...  (718) 984-6046
# 1  Come view original artworks and tree installat...  (718) 984-6046
# 2  Come view original artworks and tree installat...  (718) 984-6046
# 3  Come view original artworks and tree installat...  (718) 984-6046
# 4  Beginning May 7, 2015, the Merchant’s House Mu...  (212) 777-1089
#
#                        email  cost_free  \
# 0  admin@conferencehouse.org          1
# 1  admin@conferencehouse.org          1
# 2  admin@conferencehouse.org          1
# 3  admin@conferencehouse.org          1
# 4   emily@merchantshouse.org          0
#
#                                     cost_description  must_see  \
# 0                                                NaN         0
# 1                                                NaN         0
# 2                                                NaN         0
# 3                                                NaN         0
# 4  Admission is $10, $5 seniors & students, Free ...         0
#
#                                                  url  notice  is_event  \
# 0                            resiliency-and-elements       0         1
# 1                            resiliency-and-elements       0         1
# 2                            resiliency-and-elements       0         1
# 3                            resiliency-and-elements       0         1
# 4  thursday-evening-hours-at-the-merchants-house-...       0         1
#
#    event_duration       DOW  TOD  is_weekend  \
# 0           360.0  Saturday   11         1.0
# 1           360.0  Saturday   11         1.0
# 2           360.0  Saturday   11         1.0
# 3           360.0  Saturday   11         1.0
# 4           480.0  Thursday   12         0.0
#
#                                  name_x park_id        lat       long  \
# 0  Conference House Park Visitor Center    R006  40.502602 -74.251801
# 1  Conference House Park Visitor Center    R006  40.502602 -74.251801
# 2  Conference House Park Visitor Center    R006  40.502602 -74.251801
# 3  Conference House Park Visitor Center    R006  40.502602 -74.251801
# 4               Merchant's House Museum    M318  40.727699 -73.992302
#
#                 address      zip borough  accessible  \
# 0  298 Satterlee Street      NaN       R         1.0
# 1  298 Satterlee Street      NaN       R         1.0
# 2  298 Satterlee Street      NaN       R         1.0
# 3  298 Satterlee Street      NaN       R         1.0
# 4    29 East 4th Street  10003.0       M         0.0
#
#                                       Location 1                      name_y  \
# 0  (40.50260162353500000, -74.25180053710900000)               Arts & Crafts
# 1  (40.50260162353500000, -74.25180053710900000)                         Art
# 2  (40.50260162353500000, -74.25180053710900000)                     Markets
# 3  (40.50260162353500000, -74.25180053710900000)                     Seniors
# 4  (40.72769927978515600, -73.99230194091797000)  Historic House Trust Sites
#
#            event_organizer
# 0    Conference House Park
# 1    Conference House Park
# 2    Conference House Park
# 3    Conference House Park
# 4  Merchant's House Museum

# %%
merged_df.isnull().sum()
# Out:
# event_id                    0
# title                       0
# date                        0
# start_time                  0
# end_time                    0
# location_description    32373
# description                 0
# snippet                    12
# phone                    6858
# email                    9380
# cost_free                   0
# cost_description        33826
# must_see                    0
# url                         4
# notice                      0
# is_event                    0
# event_duration              0
# DOW                         0
# TOD                         0
# is_weekend                  0
# name_x                      0
# park_id                  3977
# lat                         0
# long                        0
# address                 19123
# zip                     17440
# borough                   696
# accessible              18799
# Location 1                  0
# name_y                      0
# event_organizer             0
# dtype: int64

# %%
test = merged_df.groupby('name_y')[['event_id','is_weekend']].count().reset_index()

# %%
test[test.is_weekend == 0.0]
# Out:
# Empty DataFrame
# Columns: [name_y, event_id, is_weekend]
# Index: []

# %%
test.sort_values('event_id', ascending=False)
# Out:
#                                                 name_y  event_id  is_weekend
# 8                                        Best for Kids      3352        3352
# 75                                              Nature      2778        2778
# 2                                                  Art      2273        2273
# 29                                           Education      2156        2156
# 38                                             Fitness      2023        2023
# 0                                           Accessible      1949        1949
# 101                                              Tours      1640        1640
# 56                                             History      1485        1485
# 91                                             Seniors      1432        1432
# 80                                     Outdoor Fitness      1316        1316
# 104                                          Volunteer      1224        1224
# 5                                        Arts & Crafts      1223        1223
# 105                                         Waterfront      1135        1135
# 94                                              Sports      1059        1059
# 35                                                Film       856         856
# 77                            Northern Manhattan Parks       810         810
# 58                                        It's My Park       764         764
# 44                                  Free Summer Movies       744         744
# 70                              Movies Under the Stars       696         696
# 84                             Poe Park Visitor Center       688         688
# 102                                 Urban Park Rangers       603         603
# 25                                               Dance       542         542
# 23                                            Concerts       444         444
# 98                                               Talks       430         430
# 100                                            Theater       424         424
# 106                                           Wildlife       417         417
# 34                                           Festivals       416         416
# 41                               Fort Tryon Park Trust       407         407
# 47                                               Games       380         380
# 96                                Summer on the Hudson       369         369
# 39                                                Food       368         368
# 43                                Free Summer Concerts       296         296
# 10                                             Birding       275         275
# 55                          Historic House Trust Sites       271         271
# 48                                   GreenThumb Events       232         232
# 109                               Youth Tech Workshops       220         220
# 45                                 Free Summer Theater       218         218
# 59                               Kayaking and Canoeing       217         217
# 52                                              Hiking       217         217
# 16                               City Parks Foundation       216         216
# 49                           GreenThumb Partner Events       212         212
# 107                                    Winter Holidays       212         212
# 3               Art in the Parks: Celebrating 50 Years       198         198
# 51                                           Halloween       173         173
# 19                                 CityParks Kids Arts       141         141
# 6                           Arts, Culture & Fun Series       131         131
# 50                                GreenThumb Workshops       127         127
# 64                                             Markets       119         119
# 17                        City Parks Foundation Adults       117         117
# 90                                        School Break       114         114
# 108                              Women's History Month        97          97
# 31                                        Fall Foliage        81          81
# 99                                        Thanksgiving        78          78
# 87                                             Running        74          74
# 4      Art in the Parks: UNIQLO Park Expressions Grant        67          67
# 37                                             Fishing        61          61
# 60                                           Kids Week        61          61
# 20                              CityParks PuppetMobile        59          59
# 92                            Shakespeare in the Parks        54          54
# 7                                            Astronomy        51          51
# 30                                      Fall Festivals        51          51
# 93                                   Shape Up New York        47          47
# 26                                                Dogs        45          45
# 27                               Earth Day & Arbor Day        43          43
# 40                                   Forest Park Trust        37          37
# 13                                Bronx River Greenway        30          30
# 95                            Summer Sports Experience        30          30
# 42                                      Fourth of July        28          28
# 32                                      Family Camping        23          23
# 79                                 Open House New York        23          23
# 57                                   Holiday Lightings        22          22
# 21                            Community Input Meetings        20          20
# 36                                           Fireworks        19          19
# 61                                   LGBTQ Pride Month        18          18
# 78         Ocean Breeze Track & Field Athletic Complex        18          18
# 71                              NYC Parks Senior Games        17          17
# 28                                              Easter        17          17
# 11                                 Black History Month        15          15
# 73                                 National Trails Day        13          13
# 81                               Parks Without Borders        13          13
# 33                                        Father's Day        12          12
# 22                          Community Parks Initiative        11          11
# 62                                       Learn To Ride        11          11
# 69                                        Mother's Day        10          10
# 89                              Santa's Coming to Town        10          10
# 9                                       Bike Month NYC        10          10
# 82   Partnerships for Parks Training and Grant Dead...        10          10
# 97                                         SummerStage         9           9
# 18                                   City of Water Day         9           9
# 1                                         Anchor Parks         9           9
# 103                                    Valentine's Day         8           8
# 53                             Hispanic Heritage Month         8           8
# 74                      Native American Heritage Month         7           7
# 46                                     Freshkills Park         6           6
# 63                                      Lunar New Year         6           6
# 68                         Mobile Recreation Van Event         5           5
# 67   MillionTreesNYC: Volunteer: Tree Stewardship a...         5           5
# 65               Martin Luther King Jr. Day of Service         5           5
# 85                                        Pumpkin Fest         3           3
# 54                       Historic House Trust Festival         2           2
# 72                                  National Night Out         2           2
# 12                                    Bocce Tournament         2           2
# 14                      Brooklyn Beach Sports Festival         2           2
# 15                            Cherry Blossom Festivals         2           2
# 88                                 Saint Patrick's Day         2           2
# 86                           Reforestation Stewardship         2           2
# 76                                      New Year's Eve         1           1
# 24                                             D/M/WBE         1           1
# 83               Partnerships for Parks Tree Workshops         1           1
# 66           MillionTreesNYC: Volunteer: Tree Planting         1           1
